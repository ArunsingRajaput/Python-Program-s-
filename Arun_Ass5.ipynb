# %%
print("Employee Bonus Evaluation System.")
name = input("Enter Employee Name: ")
salary = float(input("Enter Salary: "))
rating = int(input("Enter Performance Rating (1 to 5): "))

if rating == 5:
    bonus = 0.20 * salary
elif rating == 4:
    bonus = 0.15 * salary
elif rating == 3:
    bonus = 0.10 * salary
elif rating < 3:
    bonus = 0
else:
    print("Invalid Rating Entered")
    exit()

final_salary = salary + bonus

print("\n-- BONUS SUMMARY --")
print("Employee Name        :", name)
print("Performance Rating   :", rating)
print("Bonus Amount (₹)     :", bonus)
print("------------------------------------")
print("Final Salary (₹)     :", final_salary)
print("------------------------------------")
# Out:
# Employee Bonus Evaluation System.
# Enter Employee Name:  arun
# Enter Salary:  30000
# Enter Performance Rating (1 to 5):  4
# -- BONUS SUMMARY --
# Employee Name        : arun
# Performance Rating   : 4
# Bonus Amount (₹)     : 4500.0
# ------------------------------------
# Final Salary (₹)     : 34500.0
# ------------------------------------
