# %%
import numpy as np

def linear_regression():
    n = int(input("Enter number of data points: "))

    print("Enter x values:")
    x = np.array([float(input()) for _ in range(n)])

    print("Enter y values:")
    y = np.array([float(input()) for _ in range(n)])

    key = float(input("Enter x value to predict y: "))

    x_mean = x.mean()
    y_mean = y.mean()

    numerator = ((x - x_mean) * (y - y_mean)).sum()
    denominator = ((x - x_mean) ** 2).sum()
    a1 = numerator / denominator

    a0 = y_mean - a1 * x_mean

    y_ans = a0 + a1 * key

    print("Predicted y value:", y_ans)


linear_regression()
# Out:
# Enter number of data points: 4
# Enter x values:
# 1
# 2
# 3
# 4
# Enter y values:
# 1.5
# 2.5
# 3.5
# 4.5
# Enter x value to predict y: 5
# Predicted y value: 5.5
