# %%
print("Digital Dreams HR team receives intern registration details.")
name = input("Enter Intern Name: ")
age = int(input("Enter Age: "))  
email = input("Enter Email ID: ")
contact = input("Enter Contact Number: ")
percentage = float(input("Enter Graduation Percentage: ")) 

if age < 18:
    print("Rejection: Age must be 18 or above")
elif percentage < 60:
    print("Rejection: Graduation Percentage must be 60% or above")
elif not contact.isdigit() or len(contact) != 10:
    print("Rejection: Contact number must contain exactly 10 digits")
else:
    print("Intern Eligible for Internship")
# Out:
# Digital Dreams HR team receives intern registration details.
# Enter Intern Name:  as
# Enter Age:  20
# Enter Email ID:  uho
# Enter Contact Number:  1215
# Enter Graduation Percentage:  70
# Rejection: Contact number must contain exactly 10 digits
